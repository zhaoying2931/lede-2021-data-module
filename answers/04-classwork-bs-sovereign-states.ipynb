# %% [markdown]
# # 04 - More BeautifulSoup practice
# Using the soverign states Wikipedia page, you're going to identify different parts of the unconventionally

# %% [markdown]
# ## 1. Select all the rows of the first table on the page

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

pd.set_option('display.max_rows', 255)
# Out:
# /Users/yingzhao/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
# soverign states wikipedia url
states_url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states'

# %%
# request the page using GET request
states_r = requests.get(states_url)

# %%
# create a beautifulsoup object
states_bs = BeautifulSoup(states_r.text)

# %%
# select the first table
states_table = states_bs.find('table')

# %%
# select all the rows
states_trs = states_table.find_all('tr')

# %% [markdown]
# ## 2. Extract text only from all td tags
# You'll do this to identify where to separate the two tables

# %%
# loop through all the rows and extract only the text
full_table_data = []
for tr in states_trs[1:]:
    tds = tr.find_all('td')
    cells = []
    for td in tds:
        cells.append(td.text)
    full_table_data.append(cells)
full_table_data
# Out:
# [['A AAA\n', 'A AAA\n', 'A AAA\n', '\n'],
#  ['ZZZ↓ UN member states and observer states ↓\n', 'A AAA\n', 'ZZZ\n', '\n'],
#  ['ZZZAbkhazia → See Abkhazia listing\n'],
#  ['\xa0Afghanistan\xa0– Islamic Republic of Afghanistan\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Albania\xa0– Republic of Albania\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ["\xa0Algeria\xa0– People's Democratic Republic of Algeria\n",
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Andorra\xa0– Principality of Andorra\n',
#   'A UN member state\n',
#   'A None\n',
#   'Andorra is a co-principality in which the office of head of state is jointly held ex officio by the French president and the bishop of the Roman Catholic diocese of Urgell,[2] who himself is appointed with approval from the Holy See.\n'],
#  ['\xa0Angola\xa0– Republic of Angola\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Antigua and Barbuda\n',
#   'A UN member state\n',
#   'A None\n',
#   'Antigua and Barbuda is a Commonwealth realm[e] with one autonomous region, Barbuda.[f]\n'],
#  ['\xa0Argentina\xa0– Argentine Republic[g]\n',
#   'A UN member state\n',
#   'A None\n',
#   'Argentina is a federation of 23 provinces and one autonomous city.[h]\n'],
#  ['\xa0Armenia\xa0– Republic of Armenia\n',
#   'A UN member state\n',
#   'Not recognised by Pakistan.\n',
#   'Armenia is not recognised by Pakistan due to the dispute over Artsakh.[5][6][7]\n'],
#  ['ZZZArtsakh → See Artsakh listing\n'],
#  ['\xa0Australia\xa0– Commonwealth of Australia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Australia is a Commonwealth realm[e] and a federation of both states and territories. There are six states, three internal territories, six external territories and one claimed Antarctic external territory. The external territories of Australia are:\n\xa0Ashmore and Cartier Islands\n\xa0Christmas Island\n\xa0Cocos (Keeling) Islands\n\xa0Coral Sea Islands Territory\n\xa0Heard Island and McDonald Islands\n\xa0Norfolk Island\n\xa0Australian Antarctic Territory\n'],
#  ['\xa0Austria\xa0– Republic of Austria\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the European Union.[c] Austria is a federation of nine states.\n'],
#  ['\xa0Azerbaijan\xa0– Republic of Azerbaijan\n',
#   'A UN member state\n',
#   'A None\n',
#   'Azerbaijan contains one autonomous region, Nakhchivan [f] The de facto state of Artsakh has been established in the southwest of Azerbaijan.\n'],
#  ['\xa0Bahamas, The\xa0– Commonwealth of The Bahamas[9]\n',
#   'A UN member state\n',
#   'A None\n',
#   'The Bahamas is a Commonwealth realm.[e]\n'],
#  ['\xa0Bahrain\xa0– Kingdom of Bahrain\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ["\xa0Bangladesh\xa0– People's Republic of Bangladesh\n",
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Barbados\n',
#   'A UN member state\n',
#   'A None\n',
#   'Barbados is a Commonwealth realm.[e]\n'],
#  ['\xa0Belarus\xa0– Republic of Belarus\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Belgium\xa0– Kingdom of Belgium\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c] Belgium is a federation of three linguistic communities and three regions.\n'],
#  ['\xa0Belize\n',
#   'A UN member state\n',
#   'A None\n',
#   'Belize is a Commonwealth realm.[e]\n'],
#  ['\xa0Benin\xa0– Republic of Benin\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Bhutan\xa0– Kingdom of Bhutan\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Bolivia\xa0– Plurinational State of Bolivia\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Bosnia and Herzegovina\n',
#   'A UN member state\n',
#   'A None\n',
#   'Bosnia and Herzegovina has two constituent entities:\n\xa0Federation of Bosnia and Herzegovina\n\xa0Republika Srpska\nand Brčko District, a self-governing administrative district.[10]\n\n'],
#  ['\xa0Botswana\xa0– Republic of Botswana\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Brazil\xa0– Federative Republic of Brazil\n',
#   'A UN member state\n',
#   'A None\n',
#   'Brazil is a federation of 26 states and one federal district.\n'],
#  ['\xa0Brunei\xa0– Nation of Brunei, the Abode of Peace\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Bulgaria\xa0– Republic of Bulgaria\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Burkina Faso\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['ZZZBurma → See Myanmar listing\n'],
#  ['\xa0Burundi\xa0– Republic of Burundi\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Cambodia\xa0– Kingdom of Cambodia\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Cameroon\xa0– Republic of Cameroon\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Canada[i]\n',
#   'A UN member state\n',
#   'A None\n',
#   'Canada is a Commonwealth realm[e] and a federation of 10 provinces and three territories.\n'],
#  ['\xa0Cape Verde\xa0– Republic of Cabo Verde[j]\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Central African Republic\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0Chad\xa0– Republic of Chad\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0Chile\xa0– Republic of Chile\n',
#   'A UN member state\n',
#   'A None\n',
#   '[k]\n'],
#  ["\xa0China\xa0– People's Republic of China[l]\n",
#   'A UN member state\n',
#   "Partially unrecognised. B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'China contains five autonomous regions, Guangxi, Inner Mongolia, Ningxia, Tibet, and Xinjiang.[f] Additionally, it has sovereignty over the Special Administrative Regions of:\n\xa0Hong Kong\n\xa0Macau\nChina claims, but does not control, Taiwan, which is governed by a rival administration (the Republic of China) that claims all of China as its territory.[m]\nChina is not recognised by 15 UN member states and Vatican City, which, with the exception of Bhutan, all recognise Taiwan instead.[n]\n\n'],
#  ['ZZZChina, Republic of → See Taiwan listing\n'],
#  ['\xa0Colombia\xa0– Republic of Colombia\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Comoros\xa0– Union of the Comoros\n',
#   'A UN member state\n',
#   'A None\n',
#   'Comoros is a federation of three islands.[o]\n'],
#  ['\xa0Congo, Democratic Republic of the[p]\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Congo, Republic of the[q]\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['ZZZCook Islands → See Cook Islands listing\n'],
#  ['\xa0Costa Rica\xa0– Republic of Costa Rica\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ["ZZZCôte d'Ivoire → See Ivory Coast listing\n"],
#  ['\xa0Croatia\xa0– Republic of Croatia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Cuba\xa0– Republic of Cuba\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0Cyprus\xa0– Republic of Cyprus\n',
#   'A UN member state\n',
#   'Not recognised by Turkey[13]\n',
#   'Member of the EU.[c] The northeastern part of the island is the de facto state of Northern Cyprus.\nCyprus is not recognised by Turkey due to the Cyprus dispute, with Turkey recognising Northern Cyprus.\n\n'],
#  ['\xa0Czech Republic[r]\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ["ZZZDemocratic People's Republic of Korea → See Korea, North listing\n"],
#  ['ZZZDemocratic Republic of the Congo → See Congo, Democratic Republic of the listing\n'],
#  ['\xa0Denmark\xa0– Kingdom of Denmark\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c] The Kingdom of Denmark includes 2 self-governing territories:\n\xa0Faroe Islands\n\xa0Greenland\nThe continental territory of Denmark, the Faroe Islands, and Greenland form the three constituent countries of the Kingdom.[s] The Kingdom of Denmark as a whole is a member of the EU, but EU law does not apply to the Faroe Islands and Greenland.[14][15]\n\n'],
#  ['\xa0Djibouti\xa0– Republic of Djibouti\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Dominica\xa0– Commonwealth of Dominica\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Dominican Republic\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0East Timor\xa0– Democratic Republic of Timor-Leste[t]\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Ecuador\xa0– Republic of Ecuador\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Egypt\xa0– Arab Republic of Egypt\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0El Salvador\xa0– Republic of El Salvador\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Equatorial Guinea\xa0– Republic of Equatorial Guinea\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Eritrea\xa0– State of Eritrea\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Estonia\xa0– Republic of Estonia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Eswatini\xa0– Kingdom of Eswatini[u]\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Ethiopia\xa0– Federal Democratic Republic of Ethiopia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Ethiopia is a federation of nine regions and two chartered cities.\n'],
#  ['\xa0Fiji\xa0– Republic of Fiji\n',
#   'A UN member state\n',
#   'A None\n',
#   'Fiji contains one autonomous region, Rotuma.[f][16][17]\n'],
#  ['\xa0Finland\xa0– Republic of Finland\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n\xa0Åland is a neutral and demilitarised autonomous region of Finland.[f][v]\n'],
#  ['\xa0France\xa0– French Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c] France contains five overseas regions/departments; French Guiana, Guadeloupe, Martinique, Mayotte, and Réunion. France also includes the overseas territories of:\n\xa0Clipperton Island\n\xa0French Polynesia\n\xa0New Caledonia\n\xa0Saint Barthélemy\n\xa0Saint Martin\n\xa0Saint Pierre and Miquelon\n\xa0Wallis and Futuna\n\xa0French Southern and Antarctic Lands[w]\n'],
#  ['\xa0Gabon\xa0– Gabonese Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  [' \xa0Gambia, The\xa0– Republic of The Gambia[18]\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Georgia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Georgia contains two autonomous republics, Adjara and Abkhazia.[f] In Abkhazia and South Ossetia, de facto states have been formed.\n'],
#  ['\xa0Germany\xa0– Federal Republic of Germany\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c] Germany is a federation of 16 states.\n'],
#  ['\xa0Ghana\xa0– Republic of Ghana\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Greece\xa0– Hellenic Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c] Greece contains one autonomous area, Mount Athos.[19]\n'],
#  ['\xa0Grenada\n',
#   'A UN member state\n',
#   'A None\n',
#   'Grenada is a Commonwealth realm.[e]\n'],
#  ['\xa0Guatemala\xa0– Republic of Guatemala\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Guinea\xa0– Republic of Guinea[x]\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Guinea-Bissau\xa0– Republic of Guinea-Bissau\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Guyana\xa0– Co-operative Republic of Guyana\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Haiti\xa0– Republic of Haiti\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['ZZZHoly See → See Vatican City listing\n'],
#  ['\xa0Honduras\xa0– Republic of Honduras\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Hungary\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Iceland[y]\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0India\xa0– Republic of India\n',
#   'A UN member state\n',
#   'A None\n',
#   'India is a federation of 28 states and eight union territories.\n'],
#  ['\xa0Indonesia\xa0– Republic of Indonesia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Indonesia has five autonomous provinces, Aceh, Jakarta, Papua, West Papua, and Yogyakarta.[f]\n'],
#  ['\xa0Iran\xa0– Islamic Republic of Iran\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Iraq\xa0– Republic of Iraq\n',
#   'A UN member state\n',
#   'A None\n',
#   'Iraq is a federation[o][23] of 19 governorates, four of which make up the autonomous Kurdistan Region.[f]\n'],
#  ['\xa0Ireland[z]\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Israel\xa0– State of Israel\n',
#   'A UN member state\n',
#   'Partially unrecognised\n',
#   'Israel exerts strong control over the territory claimed by Palestine. Israel annexed East Jerusalem,[25] an annexation not recognised by the international community.[26] Israel maintains varying levels of control over the rest of the West Bank, and although Israel no longer has a permanent civilian or military presence in the Gaza Strip, following its unilateral disengagement, it is still considered by some to be the occupying power under international law.[27][28][29][30][31]\nIsrael is not recognised as a state by 28 UN members and the Sahrawi Arab Democratic Republic. The Palestine Liberation Organization, which enjoys recognition by a majority of UN member states as the sole representative of the Palestinian people, also does not recognise Israel.\n\n'],
#  ['\xa0Italy\xa0– Italian Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c] Italy has 5 autonomous regions, Aosta Valley, Friuli-Venezia Giulia, Sardinia, Sicily and Trentino-Alto Adige/Südtirol.[f]\n'],
#  ["\xa0Ivory Coast\xa0– Republic of Côte d'Ivoire[aa]\n",
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Jamaica\n',
#   'A UN member state\n',
#   'A None\n',
#   'Jamaica is a Commonwealth realm.[e]\n'],
#  ['\xa0Japan\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0Jordan\xa0– Hashemite Kingdom of Jordan\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Kazakhstan\xa0– Republic of Kazakhstan\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Kenya\xa0– Republic of Kenya\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Kiribati\xa0– Republic of Kiribati\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ["\xa0Korea, North\xa0– Democratic People's Republic of Korea\n",
#   'A UN member state\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'North Korea is not recognised by three UN members, France, Japan, and South Korea, the last of which claims to be the sole legitimate government of Korea.[32]\n'],
#  ['\xa0Korea, South\xa0– Republic of Korea\n',
#   'A UN member state\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'South Korea has one autonomous region, Jejudo.[f][33]\nSouth Korea is not recognised by North Korea, which claims to be the sole legitimate government of Korea.\n\n'],
#  ['ZZZKosovo → See Kosovo listing\n'],
#  ['\xa0Kuwait\xa0– State of Kuwait\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Kyrgyzstan\xa0– Kyrgyz Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ["\xa0Laos\xa0– Lao People's Democratic Republic\n",
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Latvia\xa0– Republic of Latvia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Lebanon\xa0– Lebanese Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Lesotho\xa0– Kingdom of Lesotho\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Liberia\xa0– Republic of Liberia\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Libya\xa0– State of Libya\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0Liechtenstein\xa0– Principality of Liechtenstein\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Lithuania\xa0– Republic of Lithuania\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Luxembourg\xa0– Grand Duchy of Luxembourg\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['ZZZMacedonia → See North Macedonia listing\n'],
#  ['\xa0Madagascar\xa0– Republic of Madagascar\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Malawi\xa0– Republic of Malawi\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Malaysia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Malaysia is a federation of 13 states and three federal territories.\n'],
#  ['\xa0Maldives\xa0– Republic of Maldives\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Mali\xa0– Republic of Mali\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0Malta\xa0– Republic of Malta\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Marshall Islands\xa0– Republic of the Marshall Islands\n',
#   'A UN member state\n',
#   'A None\n',
#   'Under Compact of Free Association with the United States.\n'],
#  ['\xa0Mauritania\xa0– Islamic Republic of Mauritania\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Mauritius\xa0– Republic of Mauritius\n',
#   'A UN member state\n',
#   'A None\n',
#   'Mauritius has an autonomous island, Rodrigues.[f]\n'],
#  ['\xa0Mexico\xa0– United Mexican States\n',
#   'A UN member state\n',
#   'A None\n',
#   'Mexico is a federation of 31 states and one autonomous city.\nThe Rebel Zapatista Autonomous Municipalities have de facto autonomy.\n\n'],
#  ['\xa0Micronesia\xa0– Federated States of Micronesia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Under Compact of Free Association with the United States. The Federated States of Micronesia is a federation of four states.\n'],
#  ['\xa0Moldova\xa0– Republic of Moldova\n',
#   'A UN member state\n',
#   'A None\n',
#   'Moldova has the autonomous regions of Gagauzia and Transnistria autonomous territorial unit. The latter and a city Bender is under the de facto control of Transnistria.\n'],
#  ['\xa0Monaco\xa0– Principality of Monaco\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Mongolia\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0Montenegro\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0Morocco\xa0– Kingdom of Morocco\n',
#   'A UN member state\n',
#   'A None\n',
#   'Part of the Moroccan-claimed Western Sahara is controlled by the partially recognised Sahrawi Arab Democratic Republic.\n'],
#  ['\xa0Mozambique\xa0– Republic of Mozambique\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Myanmar\xa0– Republic of the Union of Myanmar[ab]\n',
#   'A UN member state\n',
#   'A None\n',
#   'Wa State is a de facto autonomous state within Myanmar.\n'],
#  ['ZZZNagorno-Karabakh → See Artsakh listing\n'],
#  ['\xa0Namibia\xa0– Republic of Namibia\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Nauru\xa0– Republic of Nauru\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0\xa0\xa0Nepal\xa0– Federal Democratic Republic of Nepal\n',
#   'A UN member state\n',
#   'A None\n',
#   'Nepal is a federation composed of 7 provinces.\n'],
#  ['\xa0Netherlands – Kingdom of the Netherlands\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c] The Kingdom of the Netherlands includes four areas with substantial autonomy:\n\xa0Aruba\n\xa0Curaçao\n\xa0Netherlands\n\xa0Sint Maarten\nThe continental part of the Netherlands, Aruba, Curaçao, and Sint Maarten form the four constituent countries of the Kingdom. Three other overseas territories (Bonaire, Saba, and Sint Eustatius) are special municipalities of the continental Netherlands.[ac] The Kingdom of the Netherlands as a whole is a member of the EU, but EU law applies only to parts within Europe.\n\n'],
#  ['\xa0New Zealand\n',
#   'A UN member state\n',
#   'A None\n',
#   'New Zealand is a Commonwealth realm,[e] and has one dependent territory and one claimed Antarctic dependent territory of:\n\xa0Tokelau\n\xa0Ross Dependency\nThe New Zealand Government acts for the entire Realm of New Zealand in all international contexts, which has responsibilities for (but no rights of control over) two freely associated states:\n\n\xa0Cook Islands\n\xa0Niue\nThe Cook Islands and Niue have diplomatic relations with 49 and 18 UN members respectively.[34][35][36] They have full treaty-making capacity in the UN,[37] and are members of some UN specialized agencies.\n\n'],
#  ['\xa0Nicaragua\xa0– Republic of Nicaragua\n',
#   'A UN member state\n',
#   'A None\n',
#   'Nicaragua contains two autonomous regions, Atlántico Sur and Atlántico Norte.[f]\n'],
#  ['\xa0Niger\xa0– Republic of Niger\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Nigeria\xa0– Federal Republic of Nigeria\n',
#   'A UN member state\n',
#   'A None\n',
#   'Nigeria is a federation of 36 states and one federal territory.\n'],
#  ['ZZZNiue → See Niue listing\n'],
#  ['ZZZNorth Korea → See Korea, North listing\n'],
#  ['\xa0North Macedonia\xa0– Republic of North Macedonia[ad]\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['ZZZNorthern Cyprus → See Northern Cyprus listing\n'],
#  ['\xa0Norway\xa0– Kingdom of Norway\n',
#   'A UN member state\n',
#   'A None\n',
#   'Norway has two unincorporated areas in Europe:\n\xa0Svalbard is an integral part of Norway, but has a special status due to the Svalbard Treaty.\n\xa0Jan Mayen is an uninhabited island that is an integral part of Norway, although unincorporated.\nNorway has one dependent territory and two claimed Antarctic dependent territories in the Southern Hemisphere:\n\n\xa0Bouvet Island\n\xa0Peter I Island\n\xa0Queen Maud Land\n'],
#  ['\xa0Oman\xa0– Sultanate of Oman\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Pakistan\xa0– Islamic Republic of Pakistan\n',
#   'A UN member state\n',
#   'A None\n',
#   'Pakistan is a federation of four provinces and one capital territory. Pakistan exercises control over certain portions of Kashmir, but has not officially annexed any of it,[38][39] instead regarding it as a disputed territory.[40][41] The portions that it controls are divided into two territories, administered separately from Pakistan proper:\n\xa0Azad Kashmir\n\xa0Gilgit-Baltistan\nAzad Kashmir describes itself as a "self-governing state under Pakistani control", while Gilgit-Baltistan is described in its governance order as a group of "areas" with self-government.[42][43][44] These territories are not usually regarded as sovereign, as they do not fulfil the criteria set out by the declarative theory of statehood (for example, their current laws do not allow them to engage independently in relations with other states). Several state functions of these territories (such as foreign affairs and defence) are performed by Pakistan.[43][45][46]\n\n'],
#  ['\xa0Palau\xa0– Republic of Palau\n',
#   'A UN member state\n',
#   'A None\n',
#   'Under Compact of Free Association with the United States.\n'],
#  ['\xa0Palestine\xa0– State of Palestine\n',
#   'A UN observer state; member of 2 UN specialized agencies\n',
#   "Partially unrecognised. B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'The State of Palestine, declared in 1988, is not recognised as a state by Israel but has received diplomatic recognition from 138 states.[47] The proclaimed state has no agreed territorial borders, or effective control over much of the territory that it proclaimed.[48] The Palestinian National Authority is an interim administrative body formed as a result of the Oslo Accords that exercises limited autonomous jurisdiction within the Palestinian territories. In foreign relations, Palestine is represented by the Palestine Liberation Organization.[49] The State of Palestine is a member state of UNESCO,[50] UNIDO and other international organizations.[51]\n'],
#  ['\xa0Panama\xa0– Republic of Panama\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Papua New Guinea\xa0– Independent State of Papua New Guinea\n',
#   'A UN member state\n',
#   'A None\n',
#   'Papua New Guinea is a Commonwealth realm[e] with one autonomous region, Bougainville.[f]\n'],
#  ['\xa0Paraguay\xa0– Republic of Paraguay\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Peru\xa0– Republic of Peru\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['\xa0Philippines\xa0– Republic of the Philippines\n',
#   'A UN member state\n',
#   'A None\n',
#   'The Philippines contains one autonomous region, Bangsamoro.[f]\n'],
#  ['\xa0Poland\xa0– Republic of Poland\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Portugal\xa0– Portuguese Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c] Portugal contains two autonomous regions, the Azores and Madeira.[f]\n'],
#  ['ZZZPridnestrovie → See Transnistria listing\n'],
#  ['\xa0Qatar\xa0– State of Qatar\n', 'A UN member state\n', 'A None\n', '\n'],
#  ['ZZZRepublic of Korea → See Korea, South listing\n'],
#  ['ZZZRepublic of the Congo → See Congo, Republic of the listing\n'],
#  ['\xa0Romania\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Russia\xa0– Russian Federation\n',
#   'A UN member state\n',
#   'A None\n',
#   'Russia is a federation of 85\xa0federal subjects (republics, oblasts, krais, autonomous okrugs, federal cities, and an autonomous oblast). Several of the federal subjects are ethnic republics.[f]\n'],
#  ['\xa0Rwanda\xa0– Republic of Rwanda\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['ZZZSahrawi Arab Democratic Republic → See Sahrawi Arab Democratic Republic listing\n'],
#  ['\xa0Saint Kitts and Nevis\xa0– Federation of Saint Christopher and Nevis\n',
#   'A UN member state\n',
#   'A None\n',
#   'Saint Kitts and Nevis is a Commonwealth realm[e] and is a federation[o] of two islands, St. Kitts and Nevis.\n'],
#  ['\xa0Saint Lucia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Saint Lucia is a Commonwealth realm.[e]\n'],
#  ['\xa0Saint Vincent and the Grenadines\n',
#   'A UN member state\n',
#   'A None\n',
#   'Saint Vincent and the Grenadines is a Commonwealth realm.[e]\n'],
#  ['\xa0Samoa\xa0– Independent State of Samoa\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0San Marino\xa0– Republic of San Marino\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0São Tomé and Príncipe\xa0– Democratic Republic of São Tomé and Príncipe\n',
#   'A UN member state\n',
#   'A None\n',
#   'São Tomé and Príncipe contains one autonomous province, Príncipe.[f]\n'],
#  ['\xa0Saudi Arabia\xa0– Kingdom of Saudi Arabia\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Senegal\xa0– Republic of Senegal\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Serbia\xa0– Republic of Serbia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Serbia contains two autonomous regions, Vojvodina and Kosovo and Metohija.[f] The latter is under the de facto control of Kosovo.\n'],
#  ['\xa0Seychelles\xa0– Republic of Seychelles\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Sierra Leone\xa0– Republic of Sierra Leone\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Singapore\xa0– Republic of Singapore\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Slovakia\xa0– Slovak Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Slovenia\xa0– Republic of Slovenia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0Solomon Islands\n',
#   'A UN member state\n',
#   'A None\n',
#   'Solomon Islands is a Commonwealth realm.[e]\n'],
#  ['\xa0Somalia\xa0– Federal Republic of Somalia\n',
#   'A UN member state\n',
#   'A None\n',
#   'Somalia is a federation of six states. Two, Puntland and Galmudug, have self-declared autonomy, while one, Somaliland, is de facto independent.\n'],
#  ['ZZZSomaliland → See Somaliland listing\n'],
#  ['\xa0South Africa\xa0– Republic of South Africa\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['ZZZSouth Korea → See Korea, South listing\n'],
#  ['ZZZSouth Ossetia → See South Ossetia listing\n'],
#  ['\xa0South Sudan\xa0– Republic of South Sudan\n',
#   'A UN member state\n',
#   'A None\n',
#   'South Sudan is a federation of 10 states and three administrative areas.\nThe Abyei Area is a zone with "special administrative status" established by the Comprehensive Peace Agreement in 2005. It is de jure a condominium of South Sudan and Sudan, but de facto administered by two competing administrations and the United Nations.[52][53]\n'],
#  ['\xa0Spain\xa0– Kingdom of Spain\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c] Spain is divided into 17 autonomous communities and two special autonomous cities.[f][ae]\n'],
#  ['\xa0Sri Lanka\xa0– Democratic Socialist Republic of Sri Lanka[af]\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Sudan\xa0– Republic of the Sudan\n',
#   'A UN member state\n',
#   'A None\n',
#   'Sudan is a federation of 18 states.\nThe Abyei Area is a zone with "special administrative status" established by the Comprehensive Peace Agreement in 2005. It is de jure a condominium of South Sudan and Sudan, but de facto administered by two competing administrations and the United Nations.[52][53]\n'],
#  ['ZZZSudan, South → See South Sudan listing\n'],
#  ['\xa0Suriname\xa0– Republic of Suriname\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['ZZZSwaziland → See Eswatini listing\n'],
#  ['\xa0Sweden\xa0– Kingdom of Sweden\n',
#   'A UN member state\n',
#   'A None\n',
#   'Member of the EU.[c]\n'],
#  ['\xa0\xa0Switzerland\xa0– Swiss Confederation\n',
#   'A UN member state\n',
#   'A None\n',
#   'Switzerland is a federation of 26 cantons.\n'],
#  ['\xa0Syria\xa0– Syrian Arab Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   'The Syrian National Coalition, which is recognised as the legitimate representative of the Syrian people by 20 UN members, has established an interim government to rule rebel controlled territory during the Syrian civil war.\nSyria has one self-declared autonomous region: Rojava.\n\n'],
#  ['ZZZTaiwan (Republic of China) → See Taiwan listing\n'],
#  ['\xa0Tajikistan\xa0– Republic of Tajikistan\n',
#   'A UN member state\n',
#   'A None\n',
#   'Tajikistan contains one autonomous region, Gorno-Badakhshan Autonomous Province.[f]\n'],
#  ['\xa0Tanzania\xa0– United Republic of Tanzania\n',
#   'A UN member state\n',
#   'A None\n',
#   'Tanzania contains one autonomous region, Zanzibar.[f]\n'],
#  ['\xa0Thailand\xa0– Kingdom of Thailand\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['ZZZThe Bahamas → See Bahamas, The listing\n'],
#  ['ZZZThe Gambia → See Gambia, The listing\n'],
#  ['ZZZTimor-Leste → See East Timor listing\n'],
#  ['\xa0Togo\xa0– Togolese Republic\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Tonga\xa0– Kingdom of Tonga\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['ZZZTransnistria → See Transnistria listing\n'],
#  ['\xa0Trinidad and Tobago\xa0– Republic of Trinidad and Tobago\n',
#   'A UN member state\n',
#   'A None\n',
#   'Trinidad and Tobago contains one autonomous region, Tobago.[f]\n'],
#  ['\xa0Tunisia\xa0– Republic of Tunisia\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Turkey\xa0– Republic of Turkey\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Turkmenistan\xa0- Republic of Turkmenistan\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Tuvalu\n',
#   'A UN member state\n',
#   'A None\n',
#   'Tuvalu is a Commonwealth realm.[e]\n'],
#  ['\xa0Uganda\xa0– Republic of Uganda\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Ukraine\n',
#   'A UN member state\n',
#   'A None\n',
#   'Ukraine contains one autonomous region, the Autonomous Republic of Crimea,[f] which is under the de facto control of Russia, along with neighbouring Sevastopol.\n'],
#  ['\xa0United Arab Emirates\n',
#   'A UN member state\n',
#   'A None\n',
#   'The United Arab Emirates is a federation of seven emirates.\n'],
#  ['\xa0United Kingdom\xa0– United Kingdom of Great Britain and Northern Ireland\n',
#   'A UN member state\n',
#   'A None\n',
#   'The United Kingdom is a Commonwealth realm[e] consisting of four constituent countries; England, Northern Ireland, Scotland, and Wales. The United Kingdom has the following 13 overseas territories and one claimed Antarctic dependent territory:\n\xa0Akrotiri and Dhekelia\n\xa0Anguilla\n\xa0Bermuda\n\xa0British Indian Ocean Territory\n\xa0British Virgin Islands\n\xa0Cayman Islands\n\xa0Falkland Islands\n\xa0Gibraltar\n\xa0Montserrat\n\xa0Pitcairn Islands\n\xa0Saint Helena, Ascension and Tristan da Cunha\n\xa0South Georgia and the South Sandwich Islands\n\xa0Turks and Caicos Islands\n\xa0British Antarctic Territory\nThe British monarch also has direct sovereignty over three self-governing Crown dependencies:\n\n\xa0Guernsey\n\xa0Isle of Man\n\xa0Jersey\n'],
#  ['\xa0United States\xa0– United States of America\n',
#   'A UN member state\n',
#   'A None\n',
#   'The United States is a federation of 50 states, one federal district, and one incorporated territory. Additionally, the Federal government of the United States has sovereignty over 13 unincorporated territories. Of these territories, the following five are inhabited possessions:\n\xa0American Samoa\n\xa0Guam\n\xa0Northern Mariana Islands\n\xa0Puerto Rico\n\xa0U.S. Virgin Islands\nIt also has sovereignty over several uninhabited territories:\n\n\xa0Baker Island\n\xa0Howland Island\n\xa0Jarvis Island\n\xa0Johnston Atoll\n\xa0Kingman Reef\n\xa0Midway Atoll\n\xa0Navassa Island\n\xa0Wake Island\nIt also disputes sovereignty over the following two territories:\n\n\xa0Bajo Nuevo Bank\n\xa0Serranilla Bank\nThree sovereign states have become associated states of the United States under the Compact of Free Association:\n\n\xa0Marshall Islands – Republic of the Marshall Islands\n\xa0Micronesia – Federated States of Micronesia\n\xa0Palau – Republic of Palau\n'],
#  ['\xa0Uruguay\xa0– Oriental Republic of Uruguay\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Uzbekistan\xa0– Republic of Uzbekistan\n',
#   'A UN member state\n',
#   'A None\n',
#   'Uzbekistan contains one autonomous region, Karakalpakstan.[f]\n'],
#  ['\xa0Vanuatu\xa0– Republic of Vanuatu\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0\xa0Vatican City\xa0– Vatican City State\n',
#   'A UN observer state under the designation of "Holy See"; member of three UN specialized agencies and the IAEA\n',
#   'A None\n',
#   'Administered by the Holy See, a sovereign entity with diplomatic relations to 183\xa0states. This figure consists of 180 UN member states, the Cook Islands, the Republic of China (Taiwan), and the State of Palestine.[54] In addition, the European Union and the Sovereign Military Order of Malta maintain diplomatic relations with the Holy See. The Holy See is a member of the IAEA, ITU, UPU, and WIPO and a permanent observer of the UN (in the category of "Non-member State")[49] and multiple other UN System organizations. The Vatican City is governed by officials appointed by the Pope, who is the Bishop of the Diocese of Rome and ex officio sovereign of Vatican City.\n'],
#  ['\xa0Venezuela\xa0– Bolivarian Republic of Venezuela\n',
#   'A UN member state\n',
#   'A None\n',
#   'Venezuela is a federation of 23 states, one capital district, and federal dependencies.\n'],
#  ['\xa0Vietnam\xa0– Socialist Republic of Vietnam\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Yemen\xa0– Republic of Yemen\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Zambia\xa0– Republic of Zambia\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['\xa0Zimbabwe\xa0– Republic of Zimbabwe\n',
#   'A UN member state\n',
#   'A None\n',
#   '\n'],
#  ['ZZZ↑ UN member states and observer states ↑\n', 'A ZZZ\n', 'ZZZ\n', '\n'],
#  ['ZZZ\n', 'AB\n', 'B\n', '\n'],
#  ['ZZZ↓ Other states ↓\n', 'D AAA\n', 'ZZZ\n', '\n'],
#  ['\xa0Abkhazia\xa0– Republic of Abkhazia\n',
#   'D No membership\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'Recognised by Russia, Nauru, Nicaragua, Syria, Venezuela, Artsakh, South Ossetia and Transnistria.[55] Claimed in whole by Georgia as the Autonomous Republic of Abkhazia.\n'],
#  ['\xa0Artsakh\xa0– Republic of Artsakh[ag]\n',
#   'D No membership\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'A de facto independent state,[56][57][58] recognised only by Abkhazia,[59] South Ossetia[59] and Transnistria.[59][60] Claimed in whole by Azerbaijan.[61]\n'],
#  ['\xa0Cook Islands\n',
#   'D Member of eight UN specialized agencies\n',
#   'A None(See political status)\n',
#   'A state in free association with New Zealand, the Cook Islands maintains diplomatic relations with\xa052\xa0states. The Cook Islands is a member of multiple UN agencies with full treaty making capacity.[37] It shares a head of state with New Zealand as well as having shared citizenship.\n'],
#  ['\xa0Kosovo\xa0– Republic of Kosovo\n',
#   'D Member of two UN specialized agencies\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'Pursuant to United Nations Security Council Resolution 1244, Kosovo was placed under the administration of the United Nations Interim Administration Mission in Kosovo in 1999.[62] Kosovo declared independence in 2008, and it has received diplomatic recognition from\xa0113\xa0UN member states and the Republic of China, while 18 states have recognized Kosovo only to later withdraw their recognition.[63] Serbia continues to maintain its sovereignty claim over Kosovo. Other UN member states and non UN member states continue to recognise Serbian sovereignty or have taken no position on the question. Kosovo is a member of the International Monetary Fund and the World Bank Group. The Republic of Kosovo has de facto control over most of the territory, with limited control in North Kosovo.\n'],
#  ['\xa0Niue\n',
#   'D Member of five UN specialized agencies\n',
#   'A None(See political status)\n',
#   'A state in free association with New Zealand, Niue maintains diplomatic relations with\xa020\xa0states. Niue is a member of multiple UN agencies with full treaty making capacity.[37] It shares a head of state with New Zealand as well as having shared citizenship.\n'],
#  ['\xa0Northern Cyprus\xa0– Turkish Republic of Northern Cyprus\n',
#   'D No membership\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'Recognised only by Turkey. Under the name "Turkish Cypriot State", it is an observer state of the Organisation of Islamic Cooperation and the Economic Cooperation Organization. Northern Cyprus is claimed in whole by the Republic of Cyprus.[64]\n'],
#  ['\xa0Sahrawi Arab Democratic Republic\n',
#   'D No membership\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'Recognised at some stage by 84\xa0UN member states, 45 of which have since withdrawn or frozen their recognition. It is a founding member of the African Union and the Asian–African Strategic Partnership formed at the 2005 Asian–African Conference. The territories under its control, the so-called Free Zone, are claimed in whole by Morocco as part of its Southern Provinces. In turn, the Sahrawi Arab Democratic Republic claims the part of Western Sahara to the west of the Moroccan Wall controlled by Morocco. Its government resides in exile in Tindouf, Algeria.\n'],
#  ['\xa0Somaliland\xa0– Republic of Somaliland\n',
#   'D No membership\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'A de facto independent state,[56][65][66][67][68] not diplomatically recognised by any other state, claimed in whole by the Federal Republic of Somalia.[69]\n'],
#  ['\xa0South Ossetia\xa0– Republic of South Ossetia–the State of Alania\n',
#   'D No membership\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'A de facto independent state,[70] recognised by Russia, Nicaragua, Nauru, Syria, Venezuela, Abkhazia, Artsakh and Transnistria. Claimed in whole by Georgia as the Provisional Administrative Entity of South Ossetia.[71]\n'],
#  ['\xa0Taiwan\xa0– Republic of China[l]\n',
#   'D Former UN member and former permanent UN Security Council member (as Republic of China, 1945–1971)Observer in one UN specialized agency under the name "Chinese Taipei"\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'A state competing (nominally) for recognition with the People\'s Republic of China (PRC) as the government of China since 1949. The Republic of China (ROC) controls the island of Taiwan and associated islands, Quemoy, Matsu, the Pratas and parts of the Spratly Islands, and has not renounced claims over its annexed territories on the mainland.[72] The ROC is recognised by 14 UN member states and the Holy See as of 20 September 2019, none of which recognise the PRC. Additionally, one UN member (Bhutan) has refrained from recognising either the ROC or the PRC.\nThe territory of the ROC is claimed in whole by the PRC.[m] The ROC participates in international organizations under a variety of pseudonyms, most commonly "Chinese Taipei" and in the WTO it has full membership. The ROC was a founding member of the UN and enjoyed membership from 1945 to 1971, with veto power in the UN Security Council. See China and the United Nations.\n\n'],
#  ['\xa0Transnistria\xa0– Pridnestrovian Moldavian Republic\n',
#   'D No membership\n',
#   "B Claimed by Georgia Claimed by North Korea Claimed by Serbia Claimed by Somalia Claimed by the People's Republic of China Claimed by the Republic of China Claimed by South Korea Claimed by Azerbaijan Claimed by the Republic of Cyprus Disputed by Israel Claimed by Mauritius Claimed by Morocco Claimed by Moldova Claimed by Mali Claimed by Spain Claimed by Argentina\n",
#   'A de facto independent state,[56] recognised only by Abkhazia, Artsakh and South Ossetia.[55] Claimed in whole by Moldova.[73]\n'],
#  ['ZZZ↑ Other states ↑\n', 'D ZZZ\n', 'ZZZ\n', '\n'],
#  ['ZZZZ\n', 'ZZZZ\n', 'ZZZZ\n', '\n']]

# %%
# separate the first table from the second with list indexing
states_df = pd.DataFrame(full_table_data[3:226], columns=None)

# %%
states_df.head()
# Out:
#                                                    0                    1  \
# 0    Afghanistan – Islamic Republic of Afghanistan\n  A UN member state\n
# 1                    Albania – Republic of Albania\n  A UN member state\n
# 2   Algeria – People's Democratic Republic of Alg...  A UN member state\n
# 3                Andorra – Principality of Andorra\n  A UN member state\n
# 4                      Angola – Republic of Angola\n  A UN member state\n
#
#           2                                                  3
# 0  A None\n                                                 \n
# 1  A None\n                                                 \n
# 2  A None\n                                                 \n
# 3  A None\n  Andorra is a co-principality in which the offi...
# 4  A None\n                                                 \n

# %%
# separate the second table from the first with list indexing
other_states_df = pd.DataFrame(full_table_data[229:-2])

# %%
other_states_df.head()
# Out:
#                                       0  \
# 0     Abkhazia – Republic of Abkhazia\n
# 1   Artsakh – Republic of Artsakh[ag]\n
# 2                        Cook Islands\n
# 3         Kosovo – Republic of Kosovo\n
# 4                                Niue\n
#
#                                              1  \
# 0                            D No membership\n
# 1                            D No membership\n
# 2  D Member of eight UN specialized agencies\n
# 3    D Member of two UN specialized agencies\n
# 4   D Member of five UN specialized agencies\n
#
#                                                    2  \
# 0  B Claimed by Georgia Claimed by North Korea Cl...
# 1  B Claimed by Georgia Claimed by North Korea Cl...
# 2                     A None(See political status)\n
# 3  B Claimed by Georgia Claimed by North Korea Cl...
# 4                     A None(See political status)\n
#
#                                                    3
# 0  Recognised by Russia, Nauru, Nicaragua, Syria,...
# 1  A de facto independent state,[56][57][58] reco...
# 2  A state in free association with New Zealand, ...
# 3  Pursuant to United Nations Security Council Re...
# 4  A state in free association with New Zealand, ...

# %% [markdown]
# ## 3. Explore further the contents of each table
# ### a. States (table 1)
# ![image](assets/sovereign-states-tr.png)

# %%
# now separate the list based on the information we found from the data frames above and gather the nested tags from each td tag
# we also don't want rows where there is a td of colspan 4
states_list = []
for tr in states_trs[4:226]:
    tds = tr.find_all('td')
    #if(tds[0])
    cells = []
    for td in tds:
        cells.append(td)
    states_list.append(cells)

# %% [markdown]
# This is the same information as the image above except in a BeautifulSoup object and not html. Identify what information might be useful apart from the text within each td tag.
#
# -
# -
# -

# %% [markdown]
# Find those attributes in a single row using Antigua and Barbuda as an example

# %%
antigua_barbuda = states_list[5]

# %%
antigua_barbuda
# Out:
# [<td style="vertical-align:top;"><span id="Antigua_and_Barbuda"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="460" data-file-width="690" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/Flag_of_Antigua_and_Barbuda.svg/23px-Flag_of_Antigua_and_Barbuda.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/Flag_of_Antigua_and_Barbuda.svg/35px-Flag_of_Antigua_and_Barbuda.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/89/Flag_of_Antigua_and_Barbuda.svg/45px-Flag_of_Antigua_and_Barbuda.svg.png 2x" width="23"/> </span><a href="/wiki/Antigua_and_Barbuda" title="Antigua and Barbuda">Antigua and Barbuda</a></b>
#  </td>,
#  <td><span style="display:none">A</span> UN member state
#  </td>,
#  <td><span style="display:none">A</span> None
#  </td>,
#  <td style="vertical-align:top;text-align:left;font-size:90%;">Antigua and Barbuda is a <a href="/wiki/Commonwealth_realm" title="Commonwealth realm">Commonwealth realm</a><sup class="reference" id="cite_ref-realm_7-0"><a href="#cite_note-realm-7">[e]</a></sup> with one autonomous region, <a href="/wiki/Barbuda" title="Barbuda">Barbuda</a>.<sup class="reference" id="cite_ref-autonomous_9-0"><a href="#cite_note-autonomous-9">[f]</a></sup>
#  </td>]

# %%
# flag image src
antigua_barbuda[0].find('img')['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/8/89/Flag_of_Antigua_and_Barbuda.svg/23px-Flag_of_Antigua_and_Barbuda.svg.png'

# %%
# link to wikipedia page
antigua_barbuda[0].find('a')['href']
# Out:
# '/wiki/Antigua_and_Barbuda'

# %%
# list of citations
for sup in antigua_barbuda[3].find_all('sup'):
    print(sup)
# Out:
# <sup class="reference" id="cite_ref-realm_7-0"><a href="#cite_note-realm-7">[e]</a></sup>
# <sup class="reference" id="cite_ref-autonomous_9-0"><a href="#cite_note-autonomous-9">[f]</a></sup>

# %% [markdown]
# ### b. Other states

# %% [markdown]
# ### a. Other states (table 2)
# ![image](assets/sovereign-states-other-tr-1.png)
# ![image](assets/sovereign-states-other-tr-2.png)

# %%
other_states_list = []
for tr in states_trs[230:-2]:
    tds = tr.find_all('td')
    cells = []
    for td in tds:
        cells.append(td)
    other_states_list.append(cells)
other_states_list
# Out:
# [[<td style="vertical-align:top;"><span id="Abkhazia"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="300" data-file-width="600" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_the_Republic_of_Abkhazia.svg/23px-Flag_of_the_Republic_of_Abkhazia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_the_Republic_of_Abkhazia.svg/35px-Flag_of_the_Republic_of_Abkhazia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_the_Republic_of_Abkhazia.svg/46px-Flag_of_the_Republic_of_Abkhazia.svg.png 2x" width="23"/> </span><a href="/wiki/Abkhazia" title="Abkhazia">Abkhazia</a></b> – Republic of Abkhazia
#   </td>,
#   <td style="background:LemonChiffon;"><span style="display:none">D</span> No membership
#   </td>,
#   <td style="background:LightCoral;"><span style="display:none">B </span>Claimed by <a href="#Georgia">Georgia</a><span style="display:none"> Claimed by <a href="#Korea_North">North Korea</a> Claimed by <a href="#Serbia">Serbia</a> Claimed by <a href="#Somalia">Somalia</a> Claimed by the <a href="#China">People's Republic of China</a> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> Claimed by <a href="#Azerbaijan">Azerbaijan</a> Claimed by the <a href="#Cyprus">Republic of Cyprus</a> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> Claimed by <a href="#Morocco">Morocco</a> Claimed by <a href="#Moldova">Moldova</a> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;"><a href="/wiki/International_recognition_of_Abkhazia_and_South_Ossetia" title="International recognition of Abkhazia and South Ossetia">Recognised by</a> Russia, Nauru, Nicaragua, Syria, Venezuela, Artsakh, South Ossetia and Transnistria.<sup class="reference" id="cite_ref-ASOTREC_87-0"><a href="#cite_note-ASOTREC-87">[55]</a></sup> Claimed in whole by <a href="#Georgia">Georgia</a> as the <a href="/wiki/Government_of_the_Autonomous_Republic_of_Abkhazia" title="Government of the Autonomous Republic of Abkhazia">Autonomous Republic of Abkhazia</a>.
#   </td>],
#  [<td style="vertical-align:top;"><span id="Artsakh"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="540" data-file-width="1080" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Flag_of_Artsakh.svg/23px-Flag_of_Artsakh.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Flag_of_Artsakh.svg/35px-Flag_of_Artsakh.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Flag_of_Artsakh.svg/46px-Flag_of_Artsakh.svg.png 2x" width="23"/> </span><a href="/wiki/Republic_of_Artsakh" title="Republic of Artsakh">Artsakh</a></b> – Republic of Artsakh<sup class="reference" id="cite_ref-88"><a href="#cite_note-88">[ag]</a></sup>
#   </td>,
#   <td style="background:LemonChiffon;"><span style="display:none">D</span> No membership
#   </td>,
#   <td style="background:LightCoral;"><span style="display:none">B Claimed by <a href="#Georgia">Georgia</a> Claimed by <a href="#Korea_North">North Korea</a> Claimed by <a href="#Serbia">Serbia</a> Claimed by <a href="#Somalia">Somalia</a> Claimed by the <a href="#China">People's Republic of China</a> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> </span>Claimed by <a href="#Azerbaijan">Azerbaijan</a><span style="display:none"> Claimed by the <a href="#Cyprus">Republic of Cyprus</a> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> Claimed by <a href="#Morocco">Morocco</a> Claimed by <a href="#Moldova">Moldova</a> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;">A <i>de facto</i> independent state,<sup class="reference" id="cite_ref-montevideo_89-0"><a href="#cite_note-montevideo-89">[56]</a></sup><sup class="reference" id="cite_ref-90"><a href="#cite_note-90">[57]</a></sup><sup class="reference" id="cite_ref-91"><a href="#cite_note-91">[58]</a></sup> <a href="/wiki/Foreign_relations_of_Artsakh" title="Foreign relations of Artsakh">recognised only by</a> <a href="/wiki/Abkhazia" title="Abkhazia">Abkhazia</a>,<sup class="reference" id="cite_ref-NKRrecognition_92-0"><a href="#cite_note-NKRrecognition-92">[59]</a></sup> <a href="/wiki/South_Ossetia" title="South Ossetia">South Ossetia</a><sup class="reference" id="cite_ref-NKRrecognition_92-1"><a href="#cite_note-NKRrecognition-92">[59]</a></sup> and <a href="/wiki/Transnistria" title="Transnistria">Transnistria</a>.<sup class="reference" id="cite_ref-NKRrecognition_92-2"><a href="#cite_note-NKRrecognition-92">[59]</a></sup><sup class="reference" id="cite_ref-transgovt_93-0"><a href="#cite_note-transgovt-93">[60]</a></sup> Claimed in whole by <a href="#Azerbaijan">Azerbaijan</a>.<sup class="reference" id="cite_ref-94"><a href="#cite_note-94">[61]</a></sup>
#   </td>],
#  [<td style="vertical-align:top;"><span id="Cook_Islands"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/35/Flag_of_the_Cook_Islands.svg/23px-Flag_of_the_Cook_Islands.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/35/Flag_of_the_Cook_Islands.svg/35px-Flag_of_the_Cook_Islands.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/35/Flag_of_the_Cook_Islands.svg/46px-Flag_of_the_Cook_Islands.svg.png 2x" width="23"/> </span><a href="/wiki/Cook_Islands" title="Cook Islands">Cook Islands</a></b>
#   </td>,
#   <td style="background:lightgreen;"><span style="display:none">D</span> Member of eight <a href="/wiki/List_of_specialized_agencies_of_the_United_Nations" title="List of specialized agencies of the United Nations">UN specialized agencies</a>
#   </td>,
#   <td><span style="display:none">A</span> None<br/><small>(See <a href="/wiki/Political_status_of_the_Cook_Islands_and_Niue" title="Political status of the Cook Islands and Niue">political status</a>)</small>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;">A state in <a href="/wiki/Associated_state" title="Associated state">free association</a> with <a href="#New_Zealand">New Zealand</a>, the Cook Islands maintains <a href="/wiki/Foreign_relations_of_the_Cook_Islands" title="Foreign relations of the Cook Islands">diplomatic relations with 52 states</a>. The Cook Islands is a member of <a href="/wiki/List_of_specialized_agencies_of_the_United_Nations" title="List of specialized agencies of the United Nations">multiple UN agencies</a> with full treaty making capacity.<sup class="reference" id="cite_ref-untreaty1_66-1"><a href="#cite_note-untreaty1-66">[37]</a></sup> It shares a <a href="/wiki/Monarchy_of_New_Zealand" title="Monarchy of New Zealand">head of state</a> with New Zealand as well as having <a href="/wiki/New_Zealand_nationality_law" title="New Zealand nationality law">shared citizenship</a>.
#   </td>],
#  [<td style="vertical-align:top;"><span id="Kosovo"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="840" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Flag_of_Kosovo.svg/21px-Flag_of_Kosovo.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Flag_of_Kosovo.svg/32px-Flag_of_Kosovo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Flag_of_Kosovo.svg/42px-Flag_of_Kosovo.svg.png 2x" width="21"/> </span><a href="/wiki/Kosovo" title="Kosovo">Kosovo</a></b> – Republic of Kosovo
#   </td>,
#   <td style="background:lightgreen;"><span style="display:none">D</span> Member of two <a href="/wiki/List_of_specialized_agencies_of_the_United_Nations" title="List of specialized agencies of the United Nations">UN specialized agencies</a>
#   </td>,
#   <td style="background:LightCoral;"><span style="display:none">B Claimed by <a href="#Georgia">Georgia</a> Claimed by <a href="#Korea_North">North Korea</a> </span>Claimed by <a href="#Serbia">Serbia</a><span style="display:none"> Claimed by <a href="#Somalia">Somalia</a> Claimed by the <a href="#China">People's Republic of China</a> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> Claimed by <a href="#Azerbaijan">Azerbaijan</a> Claimed by the <a href="#Cyprus">Republic of Cyprus</a> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> Claimed by <a href="#Morocco">Morocco</a> Claimed by <a href="#Moldova">Moldova</a> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;">Pursuant to <a href="/wiki/United_Nations_Security_Council_Resolution_1244" title="United Nations Security Council Resolution 1244">United Nations Security Council Resolution 1244</a>, Kosovo was placed under the administration of the <a href="/wiki/United_Nations_Interim_Administration_Mission_in_Kosovo" title="United Nations Interim Administration Mission in Kosovo">United Nations Interim Administration Mission in Kosovo</a> in 1999.<sup class="reference" id="cite_ref-95"><a href="#cite_note-95">[62]</a></sup> Kosovo <a href="/wiki/2008_Kosovo_declaration_of_independence" title="2008 Kosovo declaration of independence">declared independence in 2008</a>, and it has <a href="/wiki/International_recognition_of_Kosovo" title="International recognition of Kosovo">received diplomatic recognition from 113 UN member states</a> and the <a class="mw-redirect" href="/wiki/Republic_of_China" title="Republic of China">Republic of China</a>, while 18 states have recognized Kosovo only to later withdraw their recognition.<sup class="reference" id="cite_ref-96"><a href="#cite_note-96">[63]</a></sup> Serbia continues to maintain its sovereignty claim over Kosovo. Other UN member states and non UN member states continue to recognise Serbian sovereignty or have taken no position on the question. Kosovo is a member of the <a href="/wiki/International_Monetary_Fund" title="International Monetary Fund">International Monetary Fund</a> and the <a href="/wiki/World_Bank_Group" title="World Bank Group">World Bank Group</a>. The Republic of Kosovo has <i>de facto</i> control over most of the territory, with limited control in <a href="/wiki/North_Kosovo" title="North Kosovo">North Kosovo</a>.
#   </td>],
#  [<td style="vertical-align:top;"><span id="Niue"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="300" data-file-width="600" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Niue.svg/23px-Flag_of_Niue.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Niue.svg/35px-Flag_of_Niue.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Niue.svg/46px-Flag_of_Niue.svg.png 2x" width="23"/> </span><a href="/wiki/Niue" title="Niue">Niue</a></b>
#   </td>,
#   <td style="background:lightgreen;"><span style="display:none">D</span> Member of five <a href="/wiki/List_of_specialized_agencies_of_the_United_Nations" title="List of specialized agencies of the United Nations">UN specialized agencies</a>
#   </td>,
#   <td><span style="display:none">A</span> None<br/><small>(See <a href="/wiki/Political_status_of_the_Cook_Islands_and_Niue" title="Political status of the Cook Islands and Niue">political status</a>)</small>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;">A state in <a href="/wiki/Associated_state" title="Associated state">free association</a> with <a href="#New_Zealand">New Zealand</a>, Niue maintains <a href="/wiki/Foreign_relations_of_Niue" title="Foreign relations of Niue">diplomatic relations with 20 states</a>. Niue is a member of <a href="/wiki/List_of_specialized_agencies_of_the_United_Nations" title="List of specialized agencies of the United Nations">multiple UN agencies</a> with full treaty making capacity.<sup class="reference" id="cite_ref-untreaty1_66-2"><a href="#cite_note-untreaty1-66">[37]</a></sup> It shares a <a href="/wiki/Monarchy_of_New_Zealand" title="Monarchy of New Zealand">head of state</a> with New Zealand as well as having <a href="/wiki/New_Zealand_nationality_law" title="New Zealand nationality law">shared citizenship</a>.
#   </td>],
#  [<td style="vertical-align:top;"><span id="Northern_Cyprus"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Flag_of_the_Turkish_Republic_of_Northern_Cyprus.svg/23px-Flag_of_the_Turkish_Republic_of_Northern_Cyprus.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Flag_of_the_Turkish_Republic_of_Northern_Cyprus.svg/35px-Flag_of_the_Turkish_Republic_of_Northern_Cyprus.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Flag_of_the_Turkish_Republic_of_Northern_Cyprus.svg/45px-Flag_of_the_Turkish_Republic_of_Northern_Cyprus.svg.png 2x" width="23"/> </span><a href="/wiki/Northern_Cyprus" title="Northern Cyprus">Northern Cyprus</a></b> – Turkish Republic of Northern Cyprus
#   </td>,
#   <td style="background:LemonChiffon;"><span style="display:none">D</span> No membership
#   </td>,
#   <td style="background:LightCoral;"><span style="display:none">B Claimed by <a href="#Georgia">Georgia</a> Claimed by <a href="#Korea_North">North Korea</a> Claimed by <a href="#Serbia">Serbia</a> Claimed by <a href="#Somalia">Somalia</a> Claimed by the <a href="#China">People's Republic of China</a> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> Claimed by <a href="#Azerbaijan">Azerbaijan</a> </span>Claimed by the <a href="#Cyprus">Republic of Cyprus</a><span style="display:none"> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> Claimed by <a href="#Morocco">Morocco</a> Claimed by <a href="#Moldova">Moldova</a> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;"><a href="/wiki/Foreign_relations_of_Northern_Cyprus" title="Foreign relations of Northern Cyprus">Recognised only by</a> <a href="#Turkey">Turkey</a>. Under the name "Turkish Cypriot State", it is an observer state of the <a href="/wiki/Organisation_of_Islamic_Cooperation" title="Organisation of Islamic Cooperation">Organisation of Islamic Cooperation</a> and the <a href="/wiki/Economic_Cooperation_Organization" title="Economic Cooperation Organization">Economic Cooperation Organization</a>. Northern Cyprus is claimed in whole by the <a href="#Cyprus">Republic of Cyprus</a>.<sup class="reference" id="cite_ref-97"><a href="#cite_note-97">[64]</a></sup>
#   </td>],
#  [<td style="vertical-align:top;"><span id="SADR"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="300" data-file-width="600" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/26/Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg/23px-Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/26/Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg/35px-Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/26/Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg/46px-Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg.png 2x" width="23"/> </span><a href="/wiki/Sahrawi_Arab_Democratic_Republic" title="Sahrawi Arab Democratic Republic">Sahrawi Arab Democratic Republic</a></b>
#   </td>,
#   <td style="background:LemonChiffon;"><span style="display:none">D</span> No membership
#   </td>,
#   <td style="background:LightCoral;"><span style="display:none">B Claimed by <a href="#Georgia">Georgia</a> Claimed by <a href="#Korea_North">North Korea</a> Claimed by <a href="#Serbia">Serbia</a> Claimed by <a href="#Somalia">Somalia</a> Claimed by the <a href="#China">People's Republic of China</a> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> Claimed by <a href="#Azerbaijan">Azerbaijan</a> Claimed by the <a href="#Cyprus">Republic of Cyprus</a> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> </span>Claimed by <a href="#Morocco">Morocco</a><span style="display:none"> Claimed by <a href="#Moldova">Moldova</a> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;">Recognised at some stage by <a href="/wiki/International_recognition_of_the_Sahrawi_Arab_Democratic_Republic" title="International recognition of the Sahrawi Arab Democratic Republic">84 UN member states</a>, 45 of which have since withdrawn or frozen their recognition. It is a founding member of the <a href="/wiki/African_Union" title="African Union">African Union</a> and the Asian–African Strategic Partnership formed at the 2005 <a class="mw-redirect" href="/wiki/Asian%E2%80%93African_Conference" title="Asian–African Conference">Asian–African Conference</a>. The territories under its control, the so-called <a href="/wiki/Free_Zone_(region)" title="Free Zone (region)">Free Zone</a>, are claimed in whole by <a href="#Morocco">Morocco</a> as part of its <a href="/wiki/Southern_Provinces" title="Southern Provinces">Southern Provinces</a>. In turn, the Sahrawi Arab Democratic Republic claims the part of <a href="/wiki/Western_Sahara" title="Western Sahara">Western Sahara</a> to the west of the <a class="mw-redirect" href="/wiki/Wall_(Western_Sahara)" title="Wall (Western Sahara)">Moroccan Wall</a> controlled by Morocco. Its government resides in exile in <a href="/wiki/Tindouf" title="Tindouf">Tindouf</a>, <a href="#Algeria">Algeria</a>.
#   </td>],
#  [<td style="vertical-align:top;"><span id="Somaliland"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Flag_of_Somaliland.svg/23px-Flag_of_Somaliland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Flag_of_Somaliland.svg/35px-Flag_of_Somaliland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Flag_of_Somaliland.svg/46px-Flag_of_Somaliland.svg.png 2x" width="23"/> </span><a href="/wiki/Somaliland" title="Somaliland">Somaliland</a></b> – Republic of Somaliland
#   </td>,
#   <td style="background:LemonChiffon;"><span style="display:none">D</span> No membership
#   </td>,
#   <td style="background:LightCoral;"><span style="display:none">B Claimed by <a href="#Georgia">Georgia</a> Claimed by <a href="#Korea_North">North Korea</a> Claimed by <a href="#Serbia">Serbia</a> </span>Claimed by <a href="#Somalia">Somalia</a><span style="display:none"> Claimed by the <a href="#China">People's Republic of China</a> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> Claimed by <a href="#Azerbaijan">Azerbaijan</a> Claimed by the <a href="#Cyprus">Republic of Cyprus</a> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> Claimed by <a href="#Morocco">Morocco</a> Claimed by <a href="#Moldova">Moldova</a> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;">A <i>de facto</i> independent state,<sup class="reference" id="cite_ref-montevideo_89-1"><a href="#cite_note-montevideo-89">[56]</a></sup><sup class="reference" id="cite_ref-FailureofStates_98-0"><a href="#cite_note-FailureofStates-98">[65]</a></sup><sup class="reference" id="cite_ref-AfricaReport_99-0"><a href="#cite_note-AfricaReport-99">[66]</a></sup><sup class="reference" id="cite_ref-PolSomaliland_100-0"><a href="#cite_note-PolSomaliland-100">[67]</a></sup><sup class="reference" id="cite_ref-StrangeCase_101-0"><a href="#cite_note-StrangeCase-101">[68]</a></sup> <a href="/wiki/Foreign_relations_of_Somaliland" title="Foreign relations of Somaliland">not diplomatically recognised by</a> any other state, claimed in whole by the <a href="#Somalia">Federal Republic of Somalia</a>.<sup class="reference" id="cite_ref-Somalilandprofile_102-0"><a href="#cite_note-Somalilandprofile-102">[69]</a></sup>
#   </td>],
#  [<td style="vertical-align:top;"><span id="South_Ossetia"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="300" data-file-width="600" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/12/Flag_of_South_Ossetia.svg/23px-Flag_of_South_Ossetia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/12/Flag_of_South_Ossetia.svg/35px-Flag_of_South_Ossetia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/12/Flag_of_South_Ossetia.svg/46px-Flag_of_South_Ossetia.svg.png 2x" width="23"/> </span><a href="/wiki/South_Ossetia" title="South Ossetia">South Ossetia</a></b> – Republic of South Ossetia–the State of Alania
#   </td>,
#   <td style="background:LemonChiffon;"><span style="display:none">D</span> No membership
#   </td>,
#   <td style="background:LightCoral;"><span style="display:none">B </span>Claimed by <a href="#Georgia">Georgia</a><span style="display:none"> Claimed by <a href="#Korea_North">North Korea</a> Claimed by <a href="#Serbia">Serbia</a> Claimed by <a href="#Somalia">Somalia</a> Claimed by the <a href="#China">People's Republic of China</a> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> Claimed by <a href="#Azerbaijan">Azerbaijan</a> Claimed by the <a href="#Cyprus">Republic of Cyprus</a> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> Claimed by <a href="#Morocco">Morocco</a> Claimed by <a href="#Moldova">Moldova</a> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;">A <i>de facto</i> independent state,<sup class="reference" id="cite_ref-103"><a href="#cite_note-103">[70]</a></sup> <a href="/wiki/International_recognition_of_Abkhazia_and_South_Ossetia" title="International recognition of Abkhazia and South Ossetia">recognised by</a> Russia, Nicaragua, Nauru, Syria, Venezuela, Abkhazia, Artsakh and Transnistria. Claimed in whole by <a href="#Georgia">Georgia</a> as the <a class="mw-redirect" href="/wiki/Provisional_Administrative_Entity_of_South_Ossetia" title="Provisional Administrative Entity of South Ossetia">Provisional Administrative Entity of South Ossetia</a>.<sup class="reference" id="cite_ref-cnnAbSO_104-0"><a href="#cite_note-cnnAbSO-104">[71]</a></sup>
#   </td>],
#  [<td style="vertical-align:top;"><span id="Taiwan"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/23px-Flag_of_the_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/35px-Flag_of_the_Republic_of_China.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/45px-Flag_of_the_Republic_of_China.svg.png 2x" width="23"/> </span><a href="/wiki/Taiwan" title="Taiwan">Taiwan</a></b> – Republic of China<sup class="reference" id="cite_ref-ChinaTaiwan_23-1"><a href="#cite_note-ChinaTaiwan-23">[l]</a></sup>
#   </td>,
#   <td style="background:Orchid;"><span style="display:none">D</span> <a href="/wiki/China_and_the_United_Nations" title="China and the United Nations">Former UN member</a> and former permanent <a class="mw-redirect" href="/wiki/UN_Security_Council" title="UN Security Council">UN Security Council</a> member (as Republic of China, 1945–1971)<br/>Observer in one <a href="/wiki/List_of_specialized_agencies_of_the_United_Nations" title="List of specialized agencies of the United Nations">UN specialized agency</a> under the name "<a href="/wiki/Chinese_Taipei" title="Chinese Taipei">Chinese Taipei</a>"
#   </td>,
#   <td style="background:LightCoral;"><span style="display:none">B Claimed by <a href="#Georgia">Georgia</a> Claimed by <a href="#Korea_North">North Korea</a> Claimed by <a href="#Serbia">Serbia</a> Claimed by <a href="#Somalia">Somalia</a> </span>Claimed by the <a href="#China">People's Republic of China</a><span style="display:none"> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> Claimed by <a href="#Azerbaijan">Azerbaijan</a> Claimed by the <a href="#Cyprus">Republic of Cyprus</a> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> Claimed by <a href="#Morocco">Morocco</a> Claimed by <a href="#Moldova">Moldova</a> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;">A state competing (nominally) for recognition with the <a href="/wiki/China" title="China">People's Republic of China</a> (PRC) as the government of China since 1949. The Republic of China (ROC) controls the island of <a href="/wiki/Taiwan" title="Taiwan">Taiwan</a> and associated islands, Quemoy, Matsu, the Pratas and parts of the <a href="/wiki/Spratly_Islands" title="Spratly Islands">Spratly Islands</a>, and has not renounced claims over its annexed territories on the <a href="/wiki/Mainland_China" title="Mainland China">mainland</a>.<sup class="reference" id="cite_ref-105"><a href="#cite_note-105">[72]</a></sup> The ROC is recognised by <a class="mw-redirect" href="/wiki/International_recognition_of_the_Republic_of_China" title="International recognition of the Republic of China">14</a> UN member states and the Holy See as of 20 September 2019, none of which recognise the PRC. Additionally, one UN member (<a href="/wiki/Bhutan" title="Bhutan">Bhutan</a>) has <a href="/wiki/Foreign_relations_of_Taiwan#Entities_with_no_relations_with_either_ROC_or_PRC" title="Foreign relations of Taiwan">refrained from recognising</a> either the ROC or the PRC.
#   <p>The territory of the ROC is claimed in whole by the PRC.<sup class="reference" id="cite_ref-TAI2_24-1"><a href="#cite_note-TAI2-24">[m]</a></sup> The ROC <a href="/wiki/Foreign_relations_of_Taiwan#Relations_with_international_organizations" title="Foreign relations of Taiwan">participates in international organizations</a> under a variety of pseudonyms, most commonly "<a href="/wiki/Chinese_Taipei" title="Chinese Taipei">Chinese Taipei</a>" and in the <a href="/wiki/World_Trade_Organization" title="World Trade Organization">WTO</a> it has full membership. The ROC was a founding member of the UN and enjoyed membership from 1945 to 1971, with veto power in the <a href="/wiki/United_Nations_Security_Council" title="United Nations Security Council">UN Security Council</a>. See <a href="/wiki/China_and_the_United_Nations" title="China and the United Nations">China and the United Nations</a>.
#   </p>
#   </td>],
#  [<td style="vertical-align:top;"><span id="Transnistria"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Flag_of_Transnistria_%28state%29.svg/23px-Flag_of_Transnistria_%28state%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Flag_of_Transnistria_%28state%29.svg/35px-Flag_of_Transnistria_%28state%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Flag_of_Transnistria_%28state%29.svg/46px-Flag_of_Transnistria_%28state%29.svg.png 2x" width="23"/> </span><a href="/wiki/Transnistria" title="Transnistria">Transnistria</a></b> – Pridnestrovian Moldavian Republic
#   </td>,
#   <td style="background:LemonChiffon;"><span style="display:none">D</span> No membership
#   </td>,
#   <td style="background:LightCoral;"><span style="display:none">B Claimed by <a href="#Georgia">Georgia</a> Claimed by <a href="#Korea_North">North Korea</a> Claimed by <a href="#Serbia">Serbia</a> Claimed by <a href="#Somalia">Somalia</a> Claimed by the <a href="#China">People's Republic of China</a> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> Claimed by <a href="#Azerbaijan">Azerbaijan</a> Claimed by the <a href="#Cyprus">Republic of Cyprus</a> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> Claimed by <a href="#Morocco">Morocco</a> </span>Claimed by <a href="#Moldova">Moldova</a><span style="display:none"> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#   </td>,
#   <td style="vertical-align:top;text-align:left;font-size:90%;">A <i>de facto</i> independent state,<sup class="reference" id="cite_ref-montevideo_89-2"><a href="#cite_note-montevideo-89">[56]</a></sup> <a href="/wiki/Foreign_relations_of_Transnistria" title="Foreign relations of Transnistria">recognised only by</a> Abkhazia, Artsakh and South Ossetia.<sup class="reference" id="cite_ref-ASOTREC_87-1"><a href="#cite_note-ASOTREC-87">[55]</a></sup> Claimed in whole by <a href="#Moldova">Moldova</a>.<sup class="reference" id="cite_ref-106"><a href="#cite_note-106">[73]</a></sup>
#   </td>]]

# %% [markdown]
# This is the same information as the image above except in a BeautifulSoup object and not html. Identify what information might be useful apart from the text within each td tag.
#
# -
# -
# -

# %% [markdown]
# Find those attributes in a single row using Abkhazia as an example

# %%
abkhazia = other_states_list[0]

# %%
abkhazia
# Out:
# [<td style="vertical-align:top;"><span id="Abkhazia"></span><b><span class="flagicon"><img alt="" class="thumbborder" data-file-height="300" data-file-width="600" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_the_Republic_of_Abkhazia.svg/23px-Flag_of_the_Republic_of_Abkhazia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_the_Republic_of_Abkhazia.svg/35px-Flag_of_the_Republic_of_Abkhazia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_the_Republic_of_Abkhazia.svg/46px-Flag_of_the_Republic_of_Abkhazia.svg.png 2x" width="23"/> </span><a href="/wiki/Abkhazia" title="Abkhazia">Abkhazia</a></b> – Republic of Abkhazia
#  </td>,
#  <td style="background:LemonChiffon;"><span style="display:none">D</span> No membership
#  </td>,
#  <td style="background:LightCoral;"><span style="display:none">B </span>Claimed by <a href="#Georgia">Georgia</a><span style="display:none"> Claimed by <a href="#Korea_North">North Korea</a> Claimed by <a href="#Serbia">Serbia</a> Claimed by <a href="#Somalia">Somalia</a> Claimed by the <a href="#China">People's Republic of China</a> Claimed by the <a href="#Taiwan">Republic of China</a> Claimed by <a href="#Korea_South">South Korea</a> Claimed by <a href="#Azerbaijan">Azerbaijan</a> Claimed by the <a href="#Cyprus">Republic of Cyprus</a> Disputed by <a href="#Israel">Israel</a> Claimed by <a href="#Mauritius">Mauritius</a> Claimed by <a href="#Morocco">Morocco</a> Claimed by <a href="#Moldova">Moldova</a> Claimed by <a href="#Mali">Mali</a> Claimed by <a href="#Spain">Spain</a> Claimed by <a href="#Argentina">Argentina</a></span>
#  </td>,
#  <td style="vertical-align:top;text-align:left;font-size:90%;"><a href="/wiki/International_recognition_of_Abkhazia_and_South_Ossetia" title="International recognition of Abkhazia and South Ossetia">Recognised by</a> Russia, Nauru, Nicaragua, Syria, Venezuela, Artsakh, South Ossetia and Transnistria.<sup class="reference" id="cite_ref-ASOTREC_87-0"><a href="#cite_note-ASOTREC-87">[55]</a></sup> Claimed in whole by <a href="#Georgia">Georgia</a> as the <a href="/wiki/Government_of_the_Autonomous_Republic_of_Abkhazia" title="Government of the Autonomous Republic of Abkhazia">Autonomous Republic of Abkhazia</a>.
#  </td>]

# %%
# what is in "display:none" span? labeled "claimed by/disputed by" is this valuable informtion?
str(abkhazia[2]).split('</a>')
# Out:
# ['<td style="background:LightCoral;"><span style="display:none">B </span>Claimed by <a href="#Georgia">Georgia',
#  '<span style="display:none"> Claimed by <a href="#Korea_North">North Korea',
#  ' Claimed by <a href="#Serbia">Serbia',
#  ' Claimed by <a href="#Somalia">Somalia',
#  ' Claimed by the <a href="#China">People\'s Republic of China',
#  ' Claimed by the <a href="#Taiwan">Republic of China',
#  ' Claimed by <a href="#Korea_South">South Korea',
#  ' Claimed by <a href="#Azerbaijan">Azerbaijan',
#  ' Claimed by the <a href="#Cyprus">Republic of Cyprus',
#  ' Disputed by <a href="#Israel">Israel',
#  ' Claimed by <a href="#Mauritius">Mauritius',
#  ' Claimed by <a href="#Morocco">Morocco',
#  ' Claimed by <a href="#Moldova">Moldova',
#  ' Claimed by <a href="#Mali">Mali',
#  ' Claimed by <a href="#Spain">Spain',
#  ' Claimed by <a href="#Argentina">Argentina',
#  '</span>\n</td>']

# %%
# what about the background color of the membership column? 
abkhazia[1]['style']
# Out:
# 'background:LemonChiffon;'

# %%
# "secondary" name? after " – "
str(abkhazia[0]).split('\xa0–')[1]
# Out:
# ' Republic of Abkhazia\n</td>'

# %% [markdown]
# ## 4. Extract the information from step 3 for each row
# ### a. States

# %%
states_list_4 = []
# for each tr
for tr in states_trs[4:226]:
#     tr[0] is th first td tag
    tds = tr.find_all('td')
    try:
        c = tds[0]['colspan']
    except:
        new_row = [None, None, []]
        if(tds[0].find('img')):
            new_row[0] = tds[0].find('img')['src']
        if(tds[0].find('a')):
            new_row[1] = tds[0].find('a')['href']
        if(len(tds[3].find_all('sup')) > 0):        
            for sup in tds[3].find_all('sup'):
                new_row[2].append(sup['id'])
        for td in tds:
            new_row.append(td.text)
        states_list_4.append(new_row)

# %%
states_df_4 = pd.DataFrame(states_list_4)

# %%
states_columns_4 = ['flag_img', 'wiki_link', 'citations', 'name', 'un_membership', 'dispute', 'more_info']
states_df_4.columns = states_columns_4

# %%
states_df_4.head(5)
# Out:
#                                             flag_img          wiki_link  \
# 0  //upload.wikimedia.org/wikipedia/commons/thumb...  /wiki/Afghanistan
# 1  //upload.wikimedia.org/wikipedia/commons/thumb...      /wiki/Albania
# 2  //upload.wikimedia.org/wikipedia/commons/thumb...      /wiki/Algeria
# 3  //upload.wikimedia.org/wikipedia/commons/thumb...      /wiki/Andorra
# 4  //upload.wikimedia.org/wikipedia/commons/thumb...       /wiki/Angola
#
#       citations                                               name  \
# 0            []    Afghanistan – Islamic Republic of Afghanistan\n
# 1            []                    Albania – Republic of Albania\n
# 2            []   Algeria – People's Democratic Republic of Alg...
# 3  [cite_ref-6]                Andorra – Principality of Andorra\n
# 4            []                      Angola – Republic of Angola\n
#
#          un_membership   dispute  \
# 0  A UN member state\n  A None\n
# 1  A UN member state\n  A None\n
# 2  A UN member state\n  A None\n
# 3  A UN member state\n  A None\n
# 4  A UN member state\n  A None\n
#
#                                            more_info
# 0                                                 \n
# 1                                                 \n
# 2                                                 \n
# 3  Andorra is a co-principality in which the offi...
# 4                                                 \n

# %% [markdown]
# ### b. Other states

# %%
other_states_list_4 = []
# for each tr
for tr in states_trs[230:-2]:
#     tr[0] is th first td tag
    tds = tr.find_all('td')
    try:
        c = tds[0]['colspan']
    except:
        new_row = [None, None, []]
        new_row[0] = tds[1].get('style')
        if(len(str(tds[0]).split('–')) > 0):      
            new_row[1] = str(tds[0]).split('–')
        if(tds[2].find('a')):
            new_row[2] = str(tds[2]).split('</a>')
        for td in tds:
            new_row.append(td.text)
        other_states_list_4.append(new_row)

# %%
other_states_df_4 = pd.DataFrame(other_states_list_4)

# %%
other_states_df_4.head(5)
other_states_df_4.columns = ['background_color', 'secondary_name', 'claimed_disputed', 'name', 'un_membership', 'notes', 'other_notes']

# %%
other_states_df_4.head()
# Out:
#            background_color  \
# 0  background:LemonChiffon;
# 1  background:LemonChiffon;
# 2    background:lightgreen;
# 3    background:lightgreen;
# 4    background:lightgreen;
#
#                                       secondary_name  \
# 0  [<td style="vertical-align:top;"><span id="Abk...
# 1  [<td style="vertical-align:top;"><span id="Art...
# 2  [<td style="vertical-align:top;"><span id="Coo...
# 3  [<td style="vertical-align:top;"><span id="Kos...
# 4  [<td style="vertical-align:top;"><span id="Niu...
#
#                                     claimed_disputed  \
# 0  [<td style="background:LightCoral;"><span styl...
# 1  [<td style="background:LightCoral;"><span styl...
# 2  [<td><span style="display:none">A</span> None<...
# 3  [<td style="background:LightCoral;"><span styl...
# 4  [<td><span style="display:none">A</span> None<...
#
#                                    name  \
# 0     Abkhazia – Republic of Abkhazia\n
# 1   Artsakh – Republic of Artsakh[ag]\n
# 2                        Cook Islands\n
# 3         Kosovo – Republic of Kosovo\n
# 4                                Niue\n
#
#                                  un_membership  \
# 0                            D No membership\n
# 1                            D No membership\n
# 2  D Member of eight UN specialized agencies\n
# 3    D Member of two UN specialized agencies\n
# 4   D Member of five UN specialized agencies\n
#
#                                                notes  \
# 0  B Claimed by Georgia Claimed by North Korea Cl...
# 1  B Claimed by Georgia Claimed by North Korea Cl...
# 2                     A None(See political status)\n
# 3  B Claimed by Georgia Claimed by North Korea Cl...
# 4                     A None(See political status)\n
#
#                                          other_notes
# 0  Recognised by Russia, Nauru, Nicaragua, Syria,...
# 1  A de facto independent state,[56][57][58] reco...
# 2  A state in free association with New Zealand, ...
# 3  Pursuant to United Nations Security Council Re...
# 4  A state in free association with New Zealand, ...
